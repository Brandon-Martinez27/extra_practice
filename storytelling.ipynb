# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telco = pd.read_csv('telco.csv', index_col=0, header=1)
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 1371-DWPAZ to 5893-KCLGT
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    7043 non-null   object
#  1   is_senior_citizen         7043 non-null   int64
#  2   partner                   7043 non-null   object
#  3   dependents                7043 non-null   object
#  4   phone_service             7043 non-null   int64
#  5   internet_service          7043 non-null   int64
#  6   contract_type             7043 non-null   int64
#  7   payment_type              7043 non-null   object
#  8   monthly_charges           7043 non-null   object
#  9   total_charges             7032 non-null   object
#  10  churn                     7043 non-null   object
#  11  tenure                    7043 non-null   int64
#  12  is_female                 7043 non-null   bool
# ...

# %%
telco.sample(10)
# Out:
#              gender  is_senior_citizen partner dependents  phone_service  \
# customer_id
# 9685-WKZGT     Male                  1      No         No              2
# 2135-RXIHG     Male                  0      No         No              1
# 8835-VSDSE   Female                  0     Yes         No              1
# 2982-VPSGI   Female                  0     Yes         No              2
# 4644-PIZRT     Male                  0     Yes        Yes              2
# 8232-CTLKO   Female                  0     Yes        Yes              1
# 9967-ATRFS   Female                  0      No         No              1
# 8945-MUQUF     Male                  0      No         No              2
# 7675-OZCZG   Female                  1      No         No              1
# 3752-CQSJI   Female                  0     Yes        Yes              1
#
#              internet_service  contract_type               payment_type  \
# customer_id
# ...

# %%
telco['monthly_charges'] = telco.monthly_charges.str.replace('$', '').astype('float')

# %%
telco['total_charges'] = telco.total_charges.str.replace('$', '').str.replace(',','').astype('float')

# %%
telco.drop(columns=['phone_service', 'internet_service','contract_type','average_monthly_charges','validate_monthly_charges','start_date','has_phone','has_internet','has_phone_and_internet'], inplace=True)

# %%
telco
# Out:
#              gender  is_senior_citizen partner dependents  \
# customer_id
# 1371-DWPAZ   Female                  0     Yes        Yes
# 2520-SGTTA   Female                  0     Yes        Yes
# 2775-SEFEE     Male                  0      No        Yes
# 2923-ARZLG     Male                  0     Yes        Yes
# 3115-CZMZD     Male                  0      No        Yes
# ...             ...                ...     ...        ...
# 3910-MRQOY   Female                  0     Yes         No
# 6010-DDPPW     Male                  0     Yes         No
# 7083-MIOPC   Female                  0      No         No
# 8207-VVMYB   Female                  0     Yes         No
# 5893-KCLGT   Female                  0      No        Yes
#
#                           payment_type  monthly_charges  total_charges churn  \
# customer_id
# 1371-DWPAZ     Credit card (automatic)            56.05            NaN    No
# 2520-SGTTA                Mailed check            20.00            NaN    No
# ...

# %%
sns.plot
